# %% [markdown]
# ### build 2D CNN (modified pattern from https://keras.io/examples/cifar10_cnn)

# %%
# import general dependencies
import ast          # new library: abstract syntax trees!
from matplotlib import pyplot
import numpy as np
import os
import pandas as pd

# %%
# import ML dependencies
from __future__ import print_function
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from tensorflow.keras.preprocessing import image
import lib.MakeCIFAR10StyleModel
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### define parameters

# %%
# set params
strPath = '.'
strModel = 'CIFAR10Style_doctordata_MyCity.h5'

# %% [markdown]
# ### import pictures as dataset for independent (X) vars

# %%
# create X data set
strImgPath = '../ek_scrape/img/doctordata/Online'
lstUsername = []
lstImg = []
for root, dirs, lstFile in os.walk(strImgPath):
    lstFile.sort()
    for strFile in lstFile:
        if strFile[-6:] == '00.png' and strFile != 'TraumaInTheUSA.00.png': # get first pic, and skip 1 bad rec
            print(strFile)
            lstUsername.append(strFile[:-7])
            img = pyplot.imread(strImgPath + '/' + strFile, format='jpg')
            arrImg = image.img_to_array(img)
            lstImg.append(arrImg)
arrX = np.array(lstImg)
arrX.shape
# Out:
# 13D.00.png
# 1KindOfLove.00.png
# 1PrettyFeetChef1.00.png
# 1STREAD.00.png
# 1cyndi.00.png
# 210Frances.00.png
# 210shine.00.png
# 22aries74.00.png
# 2705alicia.00.png
# 2k18blessings.00.png
# 47Strings.00.png
# 4blonde4.00.png
# 512martinez.00.png
# 51Izzy.00.png
# 5Dallamakeyahalla.00.png
# 71NOexpectations.00.png
# 76Bluesky39.00.png
# 80ma.00.png
# 81vegasgirl.00.png
# 8bellaleah8.00.png
# 96jennifer.00.png
# AEW1977.00.png
# AGirlLooking.00.png
# ATXgirl322.00.png
# Adianne70.00.png
# AkilaUno.00.png
# Alejandra3.00.png
# AlluringEJ.00.png
# Amycast1.00.png
# Andhereweareagain.00.png
# Andi010274.00.png
# Andreag11.00.png
# Angel601.00.png
# AngelbabyinSA.00.png
# Annapblp.00.png
# Armcandy13.00.png
# AshTX.00.png
# Aubie019.00.png
# Austin6702.00.png
# AydnilSantiago.00.png
# Az18714.00.png
# BBW43.00.png
# Babe62.00.png
# BabyGirlSA.00.png
# BeHappy58.00.png
# BeachSick.00.png
# Bebepong29.00.png
# Becca5013.00.png
# BelieveInDestiny2009.00.png
# Believedj.00.png
# BellaHeart7777.00.png
# Bellablonde1.00.png
# Bindykins.00.png
# Blkgrlnxtdr.00.png
# BonnBonn1970.00.png
# BossLadyCyn.00.png
# BrownEyesSA.00.png
# CALXTEX.00.png
# CMEREDAMNIT.00.png
# Caluco.00.png
# CatD5510.00.png
# Chicagogurl.00.png
# Chula7998.00.png
# Cindier.00.png
# CindyMedina50.00.png
# Coco_Loco_Bueno.00.png
# CoppertopChica.00.png
# CountryBohoGypsy.00.png
# CowgirlDiana.00.png
# CremeBruele07.00.png
# DDG_21.00.png
# DRM1931.00.png
# De1964.00.png
# DelilahZz.00.png
# DianaSeekingFriends.00.png
# DivineSimplicity.00.png
# Doubledogdare.00.png
# Dragonfly236.00.png
# ERTexasgirl.00.png
# Ebony_Eyes.00.png
# Elainel15.00.png
# Elsa150.00.png
# Emmayaa.00.png
# EnjoyLife1111.00.png
# EreMnyS.00.png
# Ericksjill.00.png
# Erika1975.00.png
# prettygirl3085.00.png
# prettylilthing512.00.png
# princessandria.00.png
# princesscharming.00.png
# rachell1120.00.png
# reddrover48.00.png
# redinsa.00.png
# rmartinez62.00.png
# roadneed101.00.png
# rockee74.00.png
# rose197402.00.png
# rubys1981.00.png
# sabelle30.00.png
# sammy716.00.png
# sandrasatx.00.png
# satxsaa26.00.png
# scubakat7.00.png
# sever1786.00.png
# sexualred2.00.png
# sexyme41.00.png
# shadesofredd.00.png
# shannadcc.00.png
# sherrimiller228.00.png
# shesliketexas.00.png
# skylight84.00.png
# sl2781.00.png
# smbd75.00.png
# smiley4uu4me.00.png
# smiley7919.00.png
# smmcou84.00.png
# southaustinnicegirl1.00.png
# southstar5.00.png
# splatina.00.png
# srort05.00.png
# stefdref.00.png
# stephgjmt.00.png
# stillwaiting4unow.00.png
# sugarg73.00.png
# sungirltx.00.png
# sunniatx.00.png
# sunshinebae.00.png
# susank2084.00.png
# susierod56.00.png
# sweetflower15.00.png
# sweetie7290.00.png
# sweetlksugar.00.png
# tallandten.00.png
# tam36tx.00.png
# tam919.00.png
# taraj77.00.png
# tastiione.00.png
# tencitodd2020.00.png
# tequilagirl69.00.png
# texasgal98323.00.png
# texasgirl1023.00.png
# texaslatina81.00.png
# texasqueen22.00.png
# texgal79.00.png
# thickgirlmonday.00.png
# tif1985.00.png
# tigerlillyintx1964.00.png
# tiki818.00.png
# tomiwa123.00.png
# toxicgaze.00.png
# trace03.00.png
# trice21.00.png
# trustworthy75.00.png
# tsw512.00.png
# twolittledogs.00.png
# txJen.00.png
# txgurlinm.00.png
# txmedic77.00.png
# tyty1219.00.png
# upintheair135.00.png
# valene42.00.png
# valkyrie5.00.png
# veronicab0627.00.png
# victoria77901.00.png
# waitingonyoutocatchme.00.png
# wineatsunset.00.png
# winkatmesexy77.00.png
# witty_socal.00.png
# wsj22.00.png
# xxxooxxooo.00.png
# zavygm06.00.png
# (572, 110, 110, 3)

# %%
# change lstUsername into dataframe--will be used to filter profiles later 
dfUsername = pd.DataFrame({'username':lstUsername})

# %% [markdown]
# ### read Profile data

# %%
# read JSON from file. "pof_output.txt" encoding is Windows-style "cp1252"
strPath = "../ek_scrape/img/doctordata/Online/pof_output.txt"
with open(strPath, 'r', encoding = 'cp1252') as file:
    strFile = file.read()
    dictProfile = ast.literal_eval(ast.literal_eval(strFile).decode("utf-8"))

# %%
# AddFieldsFromDictCol() converts one dictionary-style column into multiple discrete columns
def AddFieldsFromDictCol(df, strDictCol):
    dfTemp = df[strDictCol].apply(pd.Series) # .apply(pd.Series) is my favorite method EVER
    for strCol in dfTemp.columns:
        if strCol.strip() not in df.columns:
            df[strCol.strip()] = dfTemp[strCol]
    return df

# %%
# dump all fields to dataframe
lstCol = ['username', 'headline', 'profile_info_1', 'profile_info_2', 'interests', 'about_me_text']
dfAll = pd.DataFrame.from_dict(dictProfile, orient = 'index', columns = lstCol)

# %%
# convert dictionary-style columns to discrete columns and drop the dictionary columns
# this causes some columns to be mis-labelled--that'll be fixed below
for strCol in ['profile_info_1', 'profile_info_2']:
    dfAll = AddFieldsFromDictCol(dfAll, strCol)
    dfAll = dfAll.drop(strCol, axis=1)

# %% [markdown]
# ### reformat Profile data. Categorical cols will be tested as dependent (Y) vars

# %%
# drop all the "About" columns, records with NaN in "Details"
dfAll = dfAll[dfAll.columns.drop(list(dfAll.filter(regex='About.*')))]
dfAll = dfAll.dropna(subset=['Details'])

# %%
# build new fields from existing data
dfAll['Age'] = dfAll['Details'].str.strip().str[0:2].astype('int')
dfAll['Gender'] = dfAll['Details'].str.strip().str[12:13]
dfAll['Zodiac Sign'] = dfAll['Ethnicity'].str.split(', ').str[1]
dfAll['Ethnicity'] = dfAll['Ethnicity'].str.split(', ').str[0]
dfAll['Intent'] = dfAll['Intent'].str.replace('^\S+\s?', '')

# %%
# strip whitespace from text columns
for strCol in dfAll.columns:
    if dfAll[strCol].dtype == 'object':
        dfAll[strCol] = dfAll[strCol].str.strip()

# %%
# drop unneeded columns (some col labels are still shifted)
dfAll = dfAll[dfAll.columns.drop(['headline', 'City', 'interests', 'about_me_text',
                                  'Details', 'Profession', 'For', 'Chemistry',
                                  'Do you drink?', 'Hair Color', 'Gender', 'Interests'])]

# %%
# fix shifted column names
dfAll = dfAll.rename(columns={'Needs Test':'For', 'Do you want children?':'Do you drink?', 
                              'Marital Status':'Do you want children?', 'Do you do drugs?':'Marital Status', 
                              'Eye Color':'Hair Color', 'Do you have a car?':'Eye Color', 
                              'Do you have children?':'Do you have a car?', 
                              'Longest Relationship':'Do you have children?', 
                              'How ambitious are you?':'Longest Relationship', 
                              'Pets':'How ambitious are you?', 'Second Language':'Pets'})

# %%
# merge with dfUsername, and sort
dfFinal = pd.merge(dfAll, dfUsername, on='username')
dfFinal = dfFinal.sort_values(['username'])

# %%
dfFinal
# Out:
#                   username        Ethnicity  \
# 171                    13D            Black
# 158            1KindOfLove        Caucasian
# 239       1PrettyFeetChef1        Caucasian
# 121                1STREAD            Black
# 217                 1cyndi        Caucasian
# 191             210Frances         Hispanic
# 309               210shine         Hispanic
# 267              22aries74            Black
# 255             2705alicia         Hispanic
# 490          2k18blessings            Black
# 178              47Strings        Caucasian
# 377               4blonde4         Hispanic
# 468            512martinez         Hispanic
# 405                 51Izzy        Caucasian
# 213      5Dallamakeyahalla         Hispanic
# 22        71NOexpectations  Other Ethnicity
# 356            76Bluesky39       Mixed Race
# 414                   80ma            Black
# 268            81vegasgirl            Black
# 386            8bellaleah8        Caucasian
# 72              96jennifer         Hispanic
# 78                 AEW1977        Caucasian
# 66            AGirlLooking        Caucasian
# 214             ATXgirl322        Caucasian
# 518              Adianne70        Caucasian
# 295               AkilaUno            Black
# 449             Alejandra3         Hispanic
# 545             AlluringEJ            Black
# 325               Amycast1        Caucasian
# 452      Andhereweareagain        Caucasian
# ..                     ...              ...
# 68           texaslatina81         Hispanic
# 445           texasqueen22        Caucasian
# 157               texgal79        Caucasian
# 47         thickgirlmonday            Black
# 10                 tif1985         Hispanic
# 410     tigerlillyintx1964        Caucasian
# 80                 tiki818            Black
# 56               tomiwa123  Other Ethnicity
# 175              toxicgaze        Caucasian
# 458                trace03        Caucasian
# 137                trice21            Black
# 278          trustworthy75            Black
# 92                  tsw512        Caucasian
# 207          twolittledogs        Caucasian
# 221                  txJen        Caucasian
# 191  Hopeless Romantic   Hang Out              Socially
# 309             Foodie   Hang Out              Socially
# 267       Free Thinker   Hang Out              Socially
# 255         Adventurer  Long Term              Socially
# 490               Poet  Long Term              Socially
# 178           Humanist     Dating                    No
# 377  Hopeless Romantic  Long Term              Socially
# 468       Animal Lover     Dating              Socially
# 405       Animal Lover  Long Term              Socially
# 213         Music Snob     Dating              Socially
# 22           Beach Bum  Long Term              Socially
# 356       Free Thinker  Long Term              Socially
# 414  Hopeless Romantic     Dating                    No
# 268           Rockstar  Long Term              Socially
# 386       Animal Lover     Dating              Socially
# 72           Beach Bum     Dating              Socially
# 78   Hopeless Romantic     Dating              Socially
# 66      Film/TV Junkie  Long Term              Socially
# 214               Diva  Long Term              Socially
# 518       Animal Lover     Dating              Socially
# 295           Traveler     Dating              Socially
# 449  Hopeless Romantic  Long Term              Socially
# 545           Bookworm  Long Term              Socially
# 325         Adventurer     Dating  Often (>3times/week)
# 452  Hopeless Romantic  Long Term              Socially
# ..                 ...        ...                   ...
# 68              Crafty   Hang Out              Socially
# 445             Crafty     Dating              Socially
# 157  Hopeless Romantic  Long Term              Socially
# 47   Hopeless Romantic     Dating              Socially
# 10        Free Thinker    Friends              Socially
# 410         Adventurer  Long Term              Socially
# 80   Hopeless Romantic     Dating              Socially
# 56               Yuppy     Dating              Socially
# 175       Free Thinker  Long Term  Often (>3times/week)
# 458       Animal Lover     Dating              Socially
# 137        Fashionista     Dating              Socially
# 278  Hopeless Romantic  Long Term                    No
# 92            Traveler     Dating              Socially
# 207             Crafty  Long Term              Socially
# 221  Hopeless Romantic     Dating              Socially
# 252       Animal Lover  Long Term     Prefer Not To Say
# 472   Tattooed/Pierced  Long Term              Socially
# 248       Free Thinker     Dating              Socially
# 342           Rockstar     Dating              Socially
# 82        Free Thinker  Long Term              Socially
# 539           Bookworm     Dating              Socially
# 557           Homebody    Friends                    No
# 73        Animal Lover     Dating              Socially
# 160        Class Clown  Long Term              Socially
# 391         Adventurer  Long Term              Socially
# 247       Animal Lover  Long Term              Socially
# 63               Artsy   Hang Out              Socially
# 59           Night Owl     Dating                    No
# 88        Intellectual  Long Term              Socially
# 180        Class Clown   Hang Out              Socially
#
#       Do you want children? Marital Status   Hair Color Eye Color  \
# 171  Does not want children         Single          Red     Brown
# 158  Does not want children         Single     Blond(e)     Green
# 239  Does not want children       Divorced     Blond(e)     Green
# 121  Does not want children         Single  Mixed Color     Brown
# 217       Prefer Not To Say       Divorced        Brown     Brown
# 191  Does not want children       Divorced        Brown     Hazel
# 309  Does not want children         Single        Black     Brown
# 267  Does not want children         Single        Black     Brown
# 255           Want children         Single        Black     Brown
# 490  Does not want children       Divorced        Black     Brown
# 178  Does not want children         Single          Red     Green
# 377          Undecided/Open         Single     Blond(e)     Green
# 468       Prefer Not To Say         Single        Black     Brown
# 405          Undecided/Open       Divorced        Brown     Hazel
# 213       Prefer Not To Say         Single        Black     Brown
# 22           Undecided/Open       Divorced        Brown     Brown
# 356          Undecided/Open      Separated        Brown     Brown
# 414           Want children         Single        Black     Brown
# 268          Undecided/Open         Single  Mixed Color     Brown
# 386       Prefer Not To Say         Single        Brown     Hazel
# 72   Does not want children         Single        Brown     Brown
# 78   Does not want children       Divorced        Brown     Brown
# 66   Does not want children         Single     Blond(e)      Blue
# 214       Prefer Not To Say       Divorced     Blond(e)      Blue
# 518  Does not want children       Divorced        Brown     Hazel
# 295  Does not want children         Single        Black     Brown
# 449  Does not want children       Divorced        Black     Brown
# 545           Want children         Single        Brown     Hazel
# 325  Does not want children       Divorced        Brown      Blue
# 452  Does not want children       Divorced        Brown     Hazel
# ..                      ...            ...          ...       ...
# 68           Undecided/Open         Single         Grey     Brown
# 445       Prefer Not To Say       Divorced        Brown     Green
# 157  Does not want children      Separated        Brown     Brown
# 47        Prefer Not To Say         Single        Black     Brown
# 10        Prefer Not To Say         Single        Brown     Green
# 410  Does not want children         Single        Brown     Green
# 80           Undecided/Open         Single        Brown     Other
# 56        Prefer Not To Say         Single        Black     Brown
# 175  Does not want children         Single        Brown     Brown
# 458  Does not want children       Divorced        Brown      Blue
# 137  Does not want children         Single        Black     Brown
# 278  Does not want children       Divorced        Black     Brown
# 92           Undecided/Open       Divorced        Brown     Brown
# 207  Does not want children       Divorced     Blond(e)     Hazel
# 221       Prefer Not To Say       Divorced        Brown     Green
# 252           Want children         Single  Mixed Color     Brown
# 472  Does not want children       Divorced        Brown     Brown
# 248  Does not want children         Single        Brown     Brown
# 342  Does not want children         Single          Red      Blue
# 82           Undecided/Open         Single        Brown     Brown
# 539          Undecided/Open         Single          Red      Blue
# 557  Does not want children         Single        Black     Brown
# 73   Does not want children         Single        Black     Brown
# 160  Does not want children       Divorced     Blond(e)     Hazel
# 391  Does not want children       Divorced     Blond(e)      Blue
# 247       Prefer Not To Say         Single        Brown     Other
# 63           Undecided/Open         Single        Black     Brown
# 59   Does not want children       Divorced        Brown     Brown
# 88           Undecided/Open       Divorced        Brown     Brown
# 180          Undecided/Open         Single     Blond(e)      Grey
#
#     Do you have a car?    Do you have children? Longest Relationship  \
# 171                Yes  All my kids are over 18         Over 7 years
# 158                Yes                       No         Over 7 years
# 239                Yes  All my kids are over 18        Over 10 years
# 121                Yes  All my kids are over 18         Over 4 years
# 217                Yes                      Yes         Over 7 years
# 191                Yes  All my kids are over 18        Over 10 years
# 309                Yes  All my kids are over 18        Over 10 years
# 267                Yes                      Yes        Over 10 years
# 255                Yes                       No         Over 7 years
# 490                Yes  All my kids are over 18        Over 10 years
# 178                Yes                       No        Over 10 years
# 377                Yes                       No         Over 4 years
# 468                Yes                      Yes         Over 8 years
# 405                Yes                       No         Over 4 years
# 213                Yes                       No        Over 10 years
# 22                 Yes                       No         Over 6 years
# 356                Yes                      Yes        Over 10 years
# 414                Yes                       No          Over 1 year
# 268                Yes                      Yes         Over 3 years
# 386                Yes                       No         Over 8 years
# 72                 Yes  All my kids are over 18         Over 6 years
# 78                 Yes                      Yes        Over 10 years
# 66                 Yes  All my kids are over 18         Over 5 years
# 214                Yes                      Yes         Over 8 years
# 518                Yes                      Yes        Over 10 years
# 295                Yes  All my kids are over 18        Over 10 years
# 449                Yes  All my kids are over 18        Over 10 years
# 545                Yes                       No          Over 1 year
# 325                Yes                      Yes        Over 10 years
# 452                Yes  All my kids are over 18        Over 10 years
# ..                 ...                      ...                  ...
# 68                 Yes                      Yes        Over 10 years
# 445                Yes                      Yes         Over 3 years
# 157                Yes                      Yes         Over 8 years
# 47                  No                       No        Over 10 years
# 10                 Yes                      Yes         Over 6 years
# 410                Yes  All my kids are over 18        Over 10 years
# 80                 Yes                       No         Over 5 years
# 56                 Yes                      Yes         Over 5 years
# 175                Yes                      Yes         Over 6 years
# 458                Yes  All my kids are over 18        Over 10 years
# 137                Yes                      Yes        Over 10 years
# 278                Yes  All my kids are over 18         Over 8 years
# 92                 Yes  All my kids are over 18        Over 10 years
# 207                Yes  All my kids are over 18        Over 10 years
# 221                Yes                      Yes        Over 10 years
# 252                Yes                       No         Over 4 years
# 472                Yes                      Yes        Over 10 years
# 248                Yes                      Yes         Over 5 years
# 342                Yes  All my kids are over 18        Over 10 years
# 82                 Yes                      Yes         Over 4 years
# 539                Yes                       No         Over 5 years
# 557                Yes                       No         Over 3 years
# 73                 Yes                       No        Over 10 years
# 160                Yes  All my kids are over 18         Over 4 years
# 391                Yes  All my kids are over 18        Over 10 years
# 247                Yes  All my kids are over 18        Over 10 years
# 63                 Yes                      Yes         Over 8 years
# 59                 Yes  All my kids are over 18        Over 10 years
# 88                 Yes                      Yes        Over 10 years
# 180                Yes                       No         Over 5 years
#
#     How ambitious are you?       Pets  Age  Zodiac Sign
# 171              Ambitious        NaN   50       Cancer
# 158              Ambitious        NaN   50    Capricorn
# 239         Very Ambitious        NaN   52    Capricorn
# 121         Very Ambitious        NaN   49    Capricorn
# 217              Ambitious        NaN   56     Aquarius
# 191     Somewhat Ambitious        Dog   60        Aries
# 309          Not Ambitious        NaN   39       Taurus
# 267              Ambitious        NaN   45        Aries
# 255     Somewhat Ambitious    No Pets   38       Gemini
# 490         Very Ambitious        NaN   57    Capricorn
# 178              Ambitious    No Pets   61       Taurus
# 377              Ambitious    No Pets   48     Aquarius
# 468         Very Ambitious        NaN   42       Taurus
# 405              Ambitious        NaN   51       Pisces
# 213         Very Ambitious        NaN   54       Cancer
# 22          Very Ambitious        NaN   43        Virgo
# 356     Somewhat Ambitious        Dog   42      Scorpio
# 414              Ambitious        NaN   39    Capricorn
# 268         Very Ambitious        Dog   38       Cancer
# 386              Ambitious  Cat & Dog   38     Aquarius
# 72               Ambitious        NaN   43      Scorpio
# 78          Very Ambitious        NaN   42       Taurus
# 66      Somewhat Ambitious        NaN   53       Pisces
# 214              Ambitious        NaN   46        Aries
# 518     Somewhat Ambitious        NaN   49        Libra
# 295         Very Ambitious        NaN   48      Scorpio
# 449              Ambitious        NaN   49        Aries
# 545         Very Ambitious    No Pets   37          Leo
# 325              Ambitious        NaN   44     Aquarius
# 452     Somewhat Ambitious        NaN   51      Scorpio
# ..                     ...        ...  ...          ...
# 68               Ambitious        Dog   37  Sagittarius
# 445              Ambitious        NaN   34          Leo
# 157              Ambitious        NaN   40        Virgo
# 47      Somewhat Ambitious        NaN   59    Capricorn
# 10               Ambitious        NaN   34    Capricorn
# 410              Ambitious        NaN   55       Cancer
# 80      Somewhat Ambitious        NaN   45          Leo
# 56          Very Ambitious    No Pets   35      Scorpio
# 175              Ambitious        NaN   34       Pisces
# 458              Ambitious        NaN   51    Capricorn
# 137         Very Ambitious        Dog   42      Scorpio
# 278              Ambitious        NaN   44       Gemini
# 92      Somewhat Ambitious        Dog   40    Capricorn
# 207              Ambitious        NaN   61      Scorpio
# 221     Somewhat Ambitious        NaN   47     Aquarius
# 252              Ambitious        NaN   34      Scorpio
# 472              Ambitious        NaN   41      Scorpio
# 248              Ambitious        Dog   40  Sagittarius
# 342              Ambitious        NaN   48       Pisces
# 82               Ambitious        NaN   38       Cancer
# 539              Ambitious        Dog   35    Capricorn
# 557     Somewhat Ambitious        Dog   48       Cancer
# 73               Ambitious        Dog   60      Scorpio
# 160         Very Ambitious        NaN   39      Scorpio
# 391         Very Ambitious        NaN   57       Taurus
# 247         Very Ambitious        NaN   42        Libra
# 63          Very Ambitious        Dog   34     Aquarius
# 59          Very Ambitious        NaN   59    Capricorn
# 88          Very Ambitious    No Pets   38     Aquarius
# 180     Somewhat Ambitious        NaN   35  Sagittarius
#
# [572 rows x 18 columns]

# %% [markdown]
# ### start modeling

# %%
dfFinal['Ethnicity'].value_counts()
# Out:
# Caucasian          225
# Hispanic           180
# Black              112
# Mixed Race          29
# Other Ethnicity     14
# Asian                7
# Native American      4
# Indian               1
# Name: Ethnicity, dtype: int64

# %%
# define Y dataset
dfFinal['Ethnicity'] = dfFinal['Ethnicity'].astype('category')
dfFinal['Ethnicity_cat'] = dfFinal['Ethnicity'].cat.codes
arrY = dfFinal['Ethnicity_cat']

# %%
arrY.value_counts()
# Out:
# 2    225
# 3    180
# 1    112
# 5     29
# 7     14
# 0      7
# 6      4
# 4      1
# Name: Ethnicity_cat, dtype: int64

# %%
# create Train and Test datasets
arrTrainX, arrTestX, arrTrainY, arrTestY = train_test_split(arrX, arrY, random_state=17) # stratify=arrY)

# %%
# create model
model = lib.MakeCIFAR10StyleModel.Go(arrTrainX, arrTestX, arrTrainY, arrTestY)
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Not using data augmentation.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 429/429 [==============================] - 12s 29ms/step - loss: 0.4332 - accuracy: 0.8546
# Epoch 2/10
# 429/429 [==============================] - 12s 28ms/step - loss: 0.2988 - accuracy: 0.8753
# Epoch 3/10
# 429/429 [==============================] - 13s 30ms/step - loss: 0.2854 - accuracy: 0.8773
# Epoch 4/10
# 429/429 [==============================] - 12s 29ms/step - loss: 0.2841 - accuracy: 0.8759
# Epoch 5/10
# 429/429 [==============================] - 12s 29ms/step - loss: 0.2855 - accuracy: 0.8744
# Epoch 6/10
# 429/429 [==============================] - 12s 29ms/step - loss: 0.2829 - accuracy: 0.8770
# Epoch 7/10
# 429/429 [==============================] - 13s 29ms/step - loss: 0.2785 - accuracy: 0.8756
# Epoch 8/10
# 429/429 [==============================] - 12s 29ms/step - loss: 0.2863 - accuracy: 0.8733
# Epoch 9/10

# %%
# save model and weights
if not os.path.isdir(strPath):
    os.makedirs(strPath)
strModelPath = os.path.join(strPath, strModel)
model.save(strModelPath)
print('Saved trained model at %s ' % strModelPath)

# %%
# score trained model
arrScores = model.evaluate(arrTestX, arrTestY, verbose=1)
arrPredict = model.predict(arrTestX)
print('Test loss:', arrScores[0])
print('Test accuracy:', arrScores[1])

# %%
arrPredict
