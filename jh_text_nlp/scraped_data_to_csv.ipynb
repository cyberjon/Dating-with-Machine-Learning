# %%
# Import Dependencies
import ast          # new library: abstract syntax trees!
import pandas as pd
import pymongo
import re           # new library: regex!
import string

# %%
# read JSON from file. "pof_output.txt" encoding is Windows-style "cp1252"
strPath = "Resources/pof_output_female.txt"
with open(strPath, 'r', encoding = 'cp1252') as file:
    strFilef = file.read()
    dictProfilef = ast.literal_eval(ast.literal_eval(strFilef).decode("utf-8"))

# %%
# AddFieldsFromDictCol() converts one dictionary-style column into multiple discrete columns
def AddFieldsFromDictCol(df, strDictCol):
    dfTemp = df[strDictCol].apply(pd.Series) # .apply(pd.Series) is my favorite method EVER
    for strCol in dfTemp.columns:
        if strCol.strip() not in df.columns:
            df[strCol.strip()] = dfTemp[strCol]
    return df

# %%
# dump all fields to dataframe
lstColf = ['username', 'headline', 'profile_info_1', 'profile_info_2', 'interests', 'about_me_text']
dfAllf = pd.DataFrame.from_dict(dictProfilef, orient = 'index', columns = lstColf)
# convert dictionary-style columns to discrete columns and drop the dictionary columns
for strColf in ['profile_info_1', 'profile_info_2']:
    dfAllf = AddFieldsFromDictCol(dfAllf, strColf)
    dfAllf = dfAllf.drop(strColf, axis=1)
# dump all recs lacking basic Details entry (eg: 66 year old Male, 5' 10" (178cm), Christian - other)
dfAllf = dfAllf.dropna(subset=['Details'], thresh = 1)
# handle NaNs and whitespace
dfAllf['Hair Color'] = dfAllf['Hair Color'].str.strip()
dfAllf['Pets'] = dfAllf['Pets'].fillna('No Pets')
dfAllf['Pets'] = dfAllf['Pets'].str.strip()

# %%
dfAllf
# Out:
#                     username  \
# match_0       ShortyFire1984
# match_1          ROXYCHIC549
# match_10       tequilagirl69
# match_100     atxredneckgirl
# match_101            mel12th
# match_102         Andi010274
# match_103            nodutch
# match_104           lauranmr
# match_105             smbd75
# match_106       candipie1989
# match_107            tif1985
# match_108             De1964
# match_109          Trini1971
# match_11          FiaFia1213
# match_110         SweetJojos
# match_111           Tawdra83
# match_112       LadyTexas254
# match_113          Vigilia79
# match_114          ayoung292
# match_115      Foreverfungrl
# match_116         southstar5
# match_117          alpha3975
# match_118   71NOexpectations
# match_119      LadytexanInSA
# match_12   Wishing_on_stars1
# match_120         KarmaChris
# match_121          cat2018bf
# match_122           taty4242
# match_123           splatina
# match_124        LoveMichi83
# ...                      ...
# match_72           Bindykins
# match_73            Robin_66
# match_74          AlluringEJ
# match_75              pomk85
# match_76       Pochantas1979
# match_77               la320
# match_78         BossLadyCyn
# match_79       justlovelydee
# match_8             NiqqNiqq
# match_80       CindyMedina50
# match_81            NOLOYOLO
# match_82         ERTexasgirl
# match_83         letssmokeee
# match_84      heavensentu2me
# match_85       veronicab0627
# match_86           marlieATX
# match_87    DivineSimplicity
# match_88        charchar7105
# match_89              irose3
# match_9            jgibbon13
# match_90            Angel601
# match_91   Singlecapricorn81
# match_92     PrincipessaLisa
# match_93          ReneeAlpha
# match_94           satxsaa26
# match_95            PamIAm18
# match_96            ccuellar
# match_97              mptaht
# match_98       itllballright
# match_99           shannadcc
#
#                                                     headline  \
# match_0                    looking for honest men, no games!
# match_1    Laugh Often. Live Longer... I'm Not An Upgrade...
# match_10                             Let's live life and....
# match_100                            Foxy...read profile 1st
# match_101                                  Who wants to chat
# match_102                                I'm so over this...
# match_103              .........shhhhh.ok ok I'm on here ...
# match_104              Did I catch your eye? Don’t be shy ;)
# match_105                     FWB need not apply, ty next...
# match_106               Treat me like you want to be treated
# match_107                                         I'm single
# match_108                1 photo=no reply. Sorry. Not sorry.
# match_109                     Seeking a friend (No benefits)
# match_11                              Natural born ginger...
# match_110                                            Just me
# match_111                                              Hi hi
# match_112                                       LadyTexas254
# match_113         This isn't working. It isn't me. It's you!
# match_114               Educator by day/ Metal head by night
# match_115                           FAKE PICS ARE FOR LOSERS
# match_116                                          Hey there
# match_117                                          Let's see
# match_118                         ¡¡Catfish need NOT apply!!
# match_119              Want 1 Man to Love 100 Different Ways
# match_12                                    One in a million
# match_120                            Mom, Boss, Friend...Me!
# match_121                         Where is my Valentine?! ;)
# match_122  Ready4be with U, In U arms&live B always together
# match_123        Please be serious, feeling has to be mutual
# match_124                     Where is my God centered man??
# ...                                                      ...
# match_72                      In a Temporary Holding Pattern
# match_73                                             Dolphin
# match_74                                   Headline for Rent
# match_75                                          Go Cowboys
# match_76                         You should let me love you!
# match_77                                      Something real
# match_78                     New To Area..Need New Friends!!
# match_79                   I Am A Keeper....Hope You Are Too
# match_8                                         Real is rare
# match_80                         Single and ready to Mingle.
# match_81                           YOLO - you only live once
# match_82     Hello."Just be real & goodluck on your search!"
# match_83                                           Lets chil
# match_84                   Would you like to get to know me?
# match_85                                         I'm back!!!
# match_86                              Giving It Another Shot
# match_87                                        One day.....
# match_88                          I want to know your plans.
# match_89                             Artisy, Earthy Fun Lady
# match_9                     I'm thinking this is all a joke.
# match_90                                               hello
# match_91                      I’m looking for a relationship
# match_92                                        Must Love Me
# match_93                       Looking for my male archetype
# match_94                          Seeing what's out there...
# match_95                                    Hello out there!
# match_96                                     Looking for me?
# match_97                                                   .
# match_98                       Show me that 1000 watt smile.
# match_99   One day I'll meet someone good n be off this.....
#
#                                                    interests  \
# match_0                                                 None
# match_1                                                 None
# match_10                                                None
# match_100                               [LAKE, Music, Dance]
# match_101                                               None
# match_102                                               None
# match_103                                               None
# match_104                             [Music, Arts, Animals]
# match_105                                               None
# match_106                                               None
# match_107                                               None
# match_108    [Camping, Country and Western Dancing, Cooking]
# match_109                                               None
# match_11                                                None
# match_110                                               None
# match_111  [Love concerts, I play the flute so I love cla...
# match_112                                               None
# match_113                                    [IT, Tech, PTk]
# match_114                [Working with kids, Reading, Metal]
# match_115                                               None
# match_116                                               None
# match_117                                               None
# match_118      [Spartans races, Boxing, Brazilian jiu jitsu]
# match_119  [Weekend trips/ drive to near by towns site se...
# match_12                          [Live music, Beer, Travel]
# match_120                                               None
# match_121                     [Karoke, Dancing, Ice skating]
# match_122                                               None
# match_123          [Painting, Going on long walks, RELAXING]
# match_124             [Church, Christian music, Bible study]
# ...                                                      ...
# match_72                  [Traveling, Bird-watching, Hiking]
# match_73                                                None
# match_74                       [Traveling, Dancing, Cooking]
# match_75                                                None
# match_76                   [Music, Cars and Trucks, History]
# match_77                                                None
# match_78   [Drinking at sports bars, Watching Boxing And ...
# match_79                        [Cash app, Music, Traveling]
# match_8                                                 None
# match_80                                                None
# match_81                                                None
# match_82                                                None
# match_83                                                None
# match_84                                                None
# match_85                                                None
# match_86                                                None
# match_87                            [Reading, LAKE, Friends]
# match_88                               [Work, Dogs, Friends]
# match_89                         [Art, Live music, Antiques]
# match_9                                                 None
# match_90                                  [Movies, Hiking, ]
# match_91                                                None
# match_92                             [Runner, Reader, Beach]
# match_93                      [Exercising, Health, Outdoors]
# match_94                                                None
# match_95                                                None
# match_96                             [Movies, Music, Comedy]
# match_97                              [Travel, Beach, Music]
# match_98                    [Travel, Learning new recipes, ]
# match_99                                                None
#
#                                                about_me_text  \
# match_0                       ..............................
# match_1    '" I am not an upgraded member. So if you want...
# match_10   Laid back lovable fun leo looking for someone ...
# match_100  Tx country music junkie.No sickos w nasty pics...
# match_101  I am here to look for people to converse with....
# match_102  Can't get into my account so I had to start over.
# match_103  Music business goals meditation affirmation a ...
# match_104  Of all the dating profiles in all the world an...
# match_105  Likes: fun, adventure, exciting.Dislikes: bori...
# match_106  Single black female, brown eyes and black hair...
# match_107  I'm on here just looking for friends someone t...
# match_108  Please local only to Central Texas. Also while...
# match_109  I am a Mom to a 15-year-old. I was born in the...
# match_11   I like to think I am mostly just normal. I hav...
# match_110                                    Up for anything
# match_111  I’m a artist. I cook at my job and I do a lot ...
# match_112  not looking for anything serious at the moment...
# match_113  Hi there! I'm Christina: I'm not perfect and n...
# match_114  Music is life and concerts are my addiction. C...
# match_115                                         Ask me Are
# match_116          Single have two kids don't want any more.
# match_117                                 Movies dinne out..
# match_118  Just testing the waters here...NO expectations...
# match_119  Hi I am a single Hispanic divorced female...I ...
# match_12   Looking for the whole package. Someone who wan...
# match_120  I know my worth and don’t need a man to tell m...
# match_121  I'm a mother of 4 awesome teenagers!! I've bee...
# match_122  Have a great conversation, dinner, or lunch an...
# match_123  Number one reason why someone you contacted do...
# match_124  Hi, hope you are having an awesome and blessed...
# ...                                                      ...
# match_72   I'm a retired environmental geologist who enjo...
# match_73         I am a person who likes to have fun in life
# match_74   There is a lot to me but I will keep it simple...
# match_75                                 Under construction!
# match_76   I am a down to earth type of female. I have a ...
# match_77   Cooking. Road trips. Music. Family friends. Mo...
# match_78   Single, Independent, Hard Working Professional...
# match_79   I'm bSeriously Seeking A Relationship, so if y...
# match_8    You don’t have to be perfect, You just have to...
# match_80   I''m a Single Mother ,Grandmother, of 9 beauti...
# match_81   Guys I dont have a meet me....I cant answer or...
# match_82   My hobbies include watching documentaries. Lov...
# match_83                                    Ask and find out
# match_84   Looking for my happily ever after, not Mr Righ...
# match_85   Enjoy fishing, hunting,and family gatheringsBu...
# match_86   I love good food, good music, good wine, and g...
# match_87   Live music, cold beer, friends, football and t...
# match_88    Make me believe that the world hasn’t gone dead.
# match_89   I am a Artist, Love art, antiques, Live Music,...
# match_9    Harder than it seems. Not here for hook ups. S...
# match_90                                     I’ll tell later
# match_91   I’m a single mom of 3 kids the I’m youngest li...
# match_92   I love life and am passionate about God, peopl...
# match_93   I'm a huge fan of superhero movies (Marvel & D...
# match_94   Hi there, life is too short to sit at home wai...
# match_95                         Looking to meet new people.
# match_96   About me... first don't let my pics fool YOU! ...
# match_97   Howdy– thanks for stopping by. I'm here to ste...
# match_98   Music, movies, trivia. If you like these three...
# match_99   To old to waste time wondering what if .. so l...
#
#                                                   About  \
# match_0               Non-Smoker with Average body type
# match_1               Non-Smoker with Average body type
# match_10   Non-Smoker with A Few Extra Pounds body type
# match_100   Non-Smoker with Prefer Not To Say body type
# match_101      Non-Smoker with Big & Tall/BBW body type
# match_102  Non-Smoker with A Few Extra Pounds body type
# match_103            Non-Smoker with Athletic body type
# match_104      Non-Smoker with Big & Tall/BBW body type
# match_105  Non-Smoker with A Few Extra Pounds body type
# match_106      Non-Smoker with Big & Tall/BBW body type
# match_107  Non-Smoker with A Few Extra Pounds body type
# match_108  Non-Smoker with A Few Extra Pounds body type
# match_109  Non-Smoker with A Few Extra Pounds body type
# match_11              Non-Smoker with Average body type
# match_110             Non-Smoker with Average body type
# match_111  Non-Smoker with A Few Extra Pounds body type
# match_112                Non-Smoker with Thin body type
# match_113      Non-Smoker with Big & Tall/BBW body type
# match_114  Non-Smoker with A Few Extra Pounds body type
# match_115  Non-Smoker with A Few Extra Pounds body type
# match_116      Non-Smoker with Big & Tall/BBW body type
# match_117             Non-Smoker with Average body type
# match_118  Non-Smoker with A Few Extra Pounds body type
# match_119      Non-Smoker with Big & Tall/BBW body type
# match_12       Non-Smoker with Big & Tall/BBW body type
# match_120             Non-Smoker with Average body type
# match_121             Non-Smoker with Average body type
# match_122             Non-Smoker with Average body type
# match_123  Non-Smoker with A Few Extra Pounds body type
# match_124             Non-Smoker with Average body type
# ...                                                 ...
# match_72             Non-Smoker with Athletic body type
# match_73   Non-Smoker with A Few Extra Pounds body type
# match_74              Non-Smoker with Average body type
# match_75                                            NaN
# match_76              Non-Smoker with Average body type
# match_77   Non-Smoker with A Few Extra Pounds body type
# match_78   Non-Smoker with A Few Extra Pounds body type
# match_79              Non-Smoker with Average body type
# match_8               Non-Smoker with Average body type
# match_80   Non-Smoker with A Few Extra Pounds body type
# match_81              Non-Smoker with Average body type
# match_82    Non-Smoker with Prefer Not To Say body type
# match_83             Non-Smoker with Athletic body type
# match_84              Non-Smoker with Average body type
# match_85       Non-Smoker with Big & Tall/BBW body type
# match_86              Non-Smoker with Average body type
# match_87   Non-Smoker with A Few Extra Pounds body type
# match_88    Non-Smoker with Prefer Not To Say body type
# match_89              Non-Smoker with Average body type
# match_9    Non-Smoker with A Few Extra Pounds body type
# match_90              Non-Smoker with Average body type
# match_91       Non-Smoker with Big & Tall/BBW body type
# match_92              Non-Smoker with Average body type
# match_93                 Non-Smoker with Thin body type
# match_94   Non-Smoker with A Few Extra Pounds body type
# match_95              Non-Smoker with Average body type
# match_96   Non-Smoker with A Few Extra Pounds body type
# match_97             Non-Smoker with Athletic body type
# match_98       Non-Smoker with Big & Tall/BBW body type
# match_99                 Non-Smoker with Thin body type
#
#                                                  City  \
# match_0                                Austin, Texas
# match_1                                Austin, Texas
# match_10                           Round rock, Texas
# match_100                              Austin, Texas
# match_101                         San antonio, Texas
# match_102                             Bastrop, Texas
# match_103                              Austin, Texas
# match_104                                Dale, Texas
# match_105                              Austin, Texas
# match_106                              Austin, Texas
# match_107                         San antonio, Texas
# match_108                               Elgin, Texas
# match_109                              Austin, Texas
# match_11                               Austin, Texas
# match_110                              Austin, Texas
# match_111                              Austin, Texas
# match_112                              Austin, Texas
# match_113                                Kyle, Texas
# match_114                             Leander, Texas
# match_115                         San antonio, Texas
# match_116                         San antonio, Texas
# match_117                              Seguin, Texas
# match_118                         San antonio, Texas
# match_119                         San antonio, Texas
# match_12                                 Kyle, Texas
# match_120                         San antonio, Texas
# match_121                          Cedar park, Texas
# match_122                               Texas, Texas
# match_123                         San antonio, Texas
# match_124                          Round rock, Texas
# ...                                               ...
# match_72                          San antonio, Texas
# match_73                              Waelder, Texas
# match_74                               Austin, Texas
# match_75                           Round rock, Texas
# match_76                          San antonio, Texas
# match_77                           Georgetown, Texas
# match_78                               Austin, Texas
# match_79                               Austin, Texas
# match_8                                Dallas, Texas
# match_80                          San antonio, Texas
# match_81    New brunsfel / austin / las vegas, Texas
# match_82                           City of sa, Texas
# match_83                           Round rock, Texas
# match_84                Cedar creek (bastrop), Texas
# match_85                          San antonio, Texas
# match_86                               Austin, Texas
# match_87                           Round rock, Texas
# match_88                               Austin, Texas
# match_89                          San antonio, Texas
# match_9                                Cibolo, Texas
# match_90                          San antonio, Texas
# match_91                               Taylor, Texas
# match_92                          Lake travis, Texas
# match_93                               Austin, Texas
# match_94                          San antonio, Texas
# match_95                               Cibolo, Texas
# match_96                               Austin, Texas
# match_97                               Austin, Texas
# match_98                          San antonio, Texas
# match_99                          San antonio, Texas
#
#                                                      Details  \
# match_0    34 year old Female, 5' 0" (152cm), Christian -...
# match_1    62 year old Female, 5' 3" (160cm), Christian -...
# match_10   50 year old Female, 5' 2" (157cm), Christian -...
# match_100   39 year old Female, 5' 4" (163cm), Non-religious
# match_101   34 year old Female, 5' 6" (168cm), Non-religious
# match_102        45 year old Female, 5' 2" (157cm), Catholic
# match_103  45 year old Female, 5' 7" (170cm), Christian -...
# match_104   50 year old Female, 5' 6" (168cm), Non-religious
# match_105           45 year old Female, 5' 6" (168cm), Other
# match_106         48 year old Female, 5' 4" (163cm), Baptist
# match_107        34 year old Female, 5' 4" (163cm), Catholic
# match_108        55 year old Female, 5' 3" (160cm), Catholic
# match_109    47 year old Female, 5' 4" (163cm), Presbyterian
# match_11    35 year old Female, 5' 4" (163cm), Non-religious
# match_110   43 year old Female, 5' 1" (155cm), Non-religious
# match_111  36 year old Female, 5' 4" (163cm), Christian -...
# match_112  34 year old Female, 5' 3" (160cm), Christian -...
# match_113   40 year old Female, 5' 9" (175cm), Non-religious
# match_114  45 year old Female, 5' 2" (157cm), Christian -...
# match_115   43 year old Female, 5' 3" (160cm), Non-religious
# match_116           45 year old Female, 5' 6" (168cm), Other
# match_117  43 year old Female, 5' 6" (168cm), Christian -...
# match_118           43 year old Female, 5' 5" (165cm), Other
# match_119        61 year old Female, 5' 2" (157cm), Catholic
# match_12         39 year old Female, 5' 8" (173cm), Catholic
# match_120   37 year old Female, 5' 5" (165cm), Non-religious
# match_121   50 year old Female, 5' 2" (157cm), Non-religious
# match_122      52 year old Female, < 5' (< 152 cm), Catholic
# match_123  50 year old Female, 5' 4" (163cm), Christian -...
# match_124  36 year old Female, 5' 8" (173cm), Christian -...
# ...                                                      ...
# match_72    62 year old Female, 5' 3" (160cm), Non-religious
# match_73    53 year old Female, 5' 4" (163cm), Non-religious
# match_74   37 year old Female, 5' 9" (175cm), Christian -...
# match_75   52 year old Female, 5' 9" (175cm), Christian -...
# match_76    40 year old Female, 5' 5" (165cm), Non-religious
# match_77         37 year old Female, 5' 2" (157cm), Catholic
# match_78   40 year old Female, 5' 7" (170cm), Christian -...
# match_79   51 year old Female, 5' 4" (163cm), Christian -...
# match_8    34 year old Female, 5' 4" (163cm), Christian -...
# match_80         55 year old Female, 5' 4" (163cm), Catholic
# match_81         62 year old Female, 5' 0" (152cm), Catholic
# match_82         57 year old Female, 5' 5" (165cm), Catholic
# match_83    34 year old Female, 5' 6" (168cm), Non-religious
# match_84   52 year old Female, 5' 5" (165cm), Christian -...
# match_85         48 year old Female, 5' 5" (165cm), Catholic
# match_86   41 year old Female, 5' 6" (168cm), Christian -...
# match_87            43 year old Female, 5' 6" (168cm), Other
# match_88   38 year old Female, 5' 7" (170cm), Christian -...
# match_89    58 year old Female, 5' 6" (168cm), Non-religious
# match_9     42 year old Female, 5' 9" (175cm), Non-religious
# match_90           43 year old Female, 5' 5" (165cm), Muslim
# match_91   37 year old Female, 5' 6" (168cm), Christian -...
# match_92   52 year old Female, 5' 5" (165cm), Christian -...
# match_93            37 year old Female, 5' 5" (165cm), Other
# match_94         40 year old Female, 5' 2" (157cm), Lutheran
# match_95   51 year old Female, 5' 7" (170cm), Christian -...
# match_96         56 year old Female, 5' 1" (155cm), Catholic
# match_97         55 year old Female, 5' 2" (157cm), Catholic
# match_98    49 year old Female, 5' 8" (173cm), Non-religious
# match_99    43 year old Female, 5' 7" (170cm), Non-religious
#
#                            Ethnicity  \
# match_0       Caucasian, Sagittarius
# match_1       Caucasian, Sagittarius
# match_10              Caucasian, Leo
# match_100       Caucasian, Capricorn
# match_101            Hispanic, Virgo
# match_102       Caucasian, Capricorn
# match_103              Black, Taurus
# match_104          Caucasian, Taurus
# match_105  Other Ethnicity, Aquarius
# match_106               Black, Virgo
# match_107        Hispanic, Capricorn
# match_108           Caucasian, Virgo
# match_109        Indian, Sagittarius
# match_11           Caucasian, Gemini
# match_110            Hispanic, Aries
# match_111           Hispanic, Taurus
# match_112         Black, Sagittarius
# match_113           Hispanic, Cancer
# match_114             Caucasian, Leo
# match_115           Hispanic, Taurus
# match_116        Hispanic, Capricorn
# match_117          Hispanic, Scorpio
# match_118     Other Ethnicity, Virgo
# match_119      Hispanic, Sagittarius
# match_12            Hispanic, Cancer
# match_120              Hispanic, Leo
# match_121               Asian, Aries
# match_122           Hispanic, Pisces
# match_123           Hispanic, Cancer
# match_124            Hispanic, Aries
# ...                              ...
# match_72          Caucasian, Scorpio
# match_73              Caucasian, Leo
# match_74                  Black, Leo
# match_75              Caucasian, Leo
# match_76     Native American, Gemini
# match_77           Mixed Race, Aries
# match_78      Other Ethnicity, Virgo
# match_79                  Black, Leo
# match_8           Black, Sagittarius
# match_80             Hispanic, Virgo
# match_81             Hispanic, Aries
# match_82     Other Ethnicity, Pisces
# match_83            Caucasian, Virgo
# match_84            Caucasian, Libra
# match_85            Hispanic, Cancer
# match_86               Black, Gemini
# match_87          Caucasian, Scorpio
# match_88          Hispanic, Aquarius
# match_89         Caucasian, Aquarius
# match_9      Mixed Race, Sagittarius
# match_90           Caucasian, Gemini
# match_91        Caucasian, Capricorn
# match_92      Caucasian, Sagittarius
# match_93        Caucasian, Capricorn
# match_94           Caucasian, Taurus
# match_95            Black, Capricorn
# match_96            Hispanic, Gemini
# match_97           Caucasian, Taurus
# match_98      Caucasian, Sagittarius
# match_99           Caucasian, Cancer
#
#                                                       Intent  \
# match_0        ShortyFire1984 is looking for a relationship.
# match_1           ROXYCHIC549 is looking for a relationship.
# match_10   tequilagirl69 is actively seeking a relationship.
# match_100      atxredneckgirl is looking for a relationship.
# match_101         mel12th wants to date but nothing serious.
# match_102          Andi010274 is looking for a relationship.
# match_103             nodutch is looking for a relationship.
# match_104            lauranmr is looking for a relationship.
# match_105          smbd75 wants to date but nothing serious.
# match_106   candipie1989 is actively seeking a relationship.
# match_107         tif1985 wants to date but nothing serious.
# match_108              De1964 is looking for a relationship.
# match_109           Trini1971 is looking for a relationship.
# match_11           FiaFia1213 is looking for a relationship.
# match_110          SweetJojos is looking for a relationship.
# match_111       Tawdra83 is actively seeking a relationship.
# match_112        LadyTexas254 is looking for a relationship.
# match_113           Vigilia79 is looking for a relationship.
# match_114           ayoung292 is looking for a relationship.
# match_115   Foreverfungrl wants to date but nothing serious.
# match_116          southstar5 is looking for a relationship.
# match_117           alpha3975 is looking for a relationship.
# match_118  71NOexpectations is actively seeking a relatio...
# match_119       LadytexanInSA is looking for a relationship.
# match_12    Wishing_on_stars1 is looking for a relationship.
# match_120          KarmaChris is looking for a relationship.
# match_121           cat2018bf is looking for a relationship.
# match_122           taty4242 wants to find someone to marry.
# match_123           splatina wants to find someone to marry.
# match_124        LoveMichi83 wants to find someone to marry.
# ...                                                      ...
# match_72            Bindykins is looking for a relationship.
# match_73   Robin_66 isn't seeking a relationship or any k...
# match_74          AlluringEJ wants to find someone to marry.
# match_75               pomk85 is looking for a relationship.
# match_76       Pochantas1979 wants to find someone to marry.
# match_77                la320 is looking for a relationship.
# match_78      BossLadyCyn wants to date but nothing serious.
# match_79   justlovelydee is actively seeking a relationship.
# match_8              NiqqNiqq is looking for a relationship.
# match_80    CindyMedina50 wants to date but nothing serious.
# match_81            NOLOYOLO wants to find someone to marry.
# match_82          ERTexasgirl is looking for a relationship.
# match_83      letssmokeee wants to date but nothing serious.
# match_84   heavensentu2me is actively seeking a relations...
# match_85        veronicab0627 is looking for a relationship.
# match_86            marlieATX is looking for a relationship.
# match_87     DivineSimplicity is looking for a relationship.
# match_88         charchar7105 is looking for a relationship.
# match_89          irose3 is actively seeking a relationship.
# match_9        jgibbon13 is actively seeking a relationship.
# match_90        Angel601 is actively seeking a relationship.
# match_91    Singlecapricorn81 is looking for a relationship.
# match_92     PrincipessaLisa wants to find someone to marry.
# match_93       ReneeAlpha wants to date but nothing serious.
# match_94        satxsaa26 wants to date but nothing serious.
# match_95         PamIAm18 wants to date but nothing serious.
# match_96             ccuellar is looking for a relationship.
# match_97               mptaht is looking for a relationship.
# match_98   itllballright is actively seeking a relationship.
# match_99            shannadcc is looking for a relationship.
#
#                    Education  ... AboutCindie AboutJoy AboutJae AboutMonie  \
# match_0     Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_1     Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_10   Associates Degree  ...         NaN      NaN      NaN        NaN
# match_100       Some college  ...         NaN      NaN      NaN        NaN
# match_101   Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_102       Some college  ...         NaN      NaN      NaN        NaN
# match_103  Associates Degree  ...         NaN      NaN      NaN        NaN
# match_104       Some college  ...         NaN      NaN      NaN        NaN
# match_105   Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_106  Associates Degree  ...         NaN      NaN      NaN        NaN
# match_107        High school  ...         NaN      NaN      NaN        NaN
# match_108   Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_109       Some college  ...         NaN      NaN      NaN        NaN
# match_11        Some college  ...         NaN      NaN      NaN        NaN
# match_110       Some college  ...         NaN      NaN      NaN        NaN
# match_111   Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_112   Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_113  Associates Degree  ...         NaN      NaN      NaN        NaN
# match_114     Masters Degree  ...         NaN      NaN      NaN        NaN
# match_115       Some college  ...         NaN      NaN      NaN        NaN
# match_116       Some college  ...         NaN      NaN      NaN        NaN
# match_117        High school  ...         NaN      NaN      NaN        NaN
# match_118  Associates Degree  ...         NaN      NaN      NaN        NaN
# match_119       Some college  ...         NaN      NaN      NaN        NaN
# match_12        Some college  ...         NaN      NaN      NaN        NaN
# match_120   Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_121       Some college  ...         NaN      NaN      NaN        NaN
# match_122    Graduate Degree  ...         NaN      NaN      NaN        NaN
# match_123       Some college  ...         NaN      NaN      NaN        NaN
# match_124                NaN  ...         NaN      NaN      NaN        NaN
# ...                      ...  ...         ...      ...      ...        ...
# match_72    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_73         High school  ...         NaN      NaN      NaN        NaN
# match_74                 NaN  ...         NaN      NaN      NaN        NaN
# match_75        Some college  ...         NaN      NaN      NaN        NaN
# match_76        Some college  ...         NaN      NaN      NaN        NaN
# match_77        Some college  ...         NaN      NaN      NaN        NaN
# match_78   Associates Degree  ...         NaN      NaN      NaN        NaN
# match_79         High school  ...         NaN      NaN      NaN        NaN
# match_8         Some college  ...         NaN      NaN      NaN        NaN
# match_80        Some college  ...         NaN      NaN      NaN        NaN
# match_81         High school  ...         NaN      NaN      NaN        NaN
# match_82        Some college  ...         NaN      NaN      NaN        NaN
# match_83    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_84         High school  ...         NaN      NaN      NaN        NaN
# match_85         High school  ...         NaN      NaN      NaN        NaN
# match_86    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_87        Some college  ...         NaN      NaN      NaN        NaN
# match_88   Associates Degree  ...         NaN      NaN      NaN        NaN
# match_89        Some college  ...         NaN      NaN      NaN        NaN
# match_9         Some college  ...         NaN      NaN      NaN        NaN
# match_90    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_91         High school  ...         NaN      NaN      NaN        NaN
# match_92     Graduate Degree  ...         NaN      NaN      NaN        NaN
# match_93    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_94      Masters Degree  ...         NaN      NaN      NaN        NaN
# match_95    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_96        Some college  ...         NaN      NaN      NaN        NaN
# match_97      Masters Degree  ...         NaN      NaN      NaN        NaN
# match_98    Bachelors Degree  ...         NaN      NaN      NaN        NaN
# match_99         High school  ...         NaN      NaN      NaN        NaN
#
#           AboutSue AboutTerry AboutNiqq AboutLori Aboutveronica AboutKenda
# match_0        NaN        NaN       NaN       NaN           NaN        NaN
# match_1        NaN        NaN       NaN       NaN           NaN        NaN
# match_10       NaN        NaN       NaN       NaN           NaN        NaN
# match_100      NaN        NaN       NaN       NaN           NaN        NaN
# match_101      NaN        NaN       NaN       NaN           NaN        NaN
# match_102      NaN        NaN       NaN       NaN           NaN        NaN
# match_103      NaN        NaN       NaN       NaN           NaN        NaN
# match_104      NaN        NaN       NaN       NaN           NaN        NaN
# match_105      NaN        NaN       NaN       NaN           NaN        NaN
# match_106      NaN        NaN       NaN       NaN           NaN        NaN
# match_107      NaN        NaN       NaN       NaN           NaN        NaN
# match_108      NaN        NaN       NaN       NaN           NaN        NaN
# match_109      NaN        NaN       NaN       NaN           NaN        NaN
# match_11       NaN        NaN       NaN       NaN           NaN        NaN
# match_110      NaN        NaN       NaN       NaN           NaN        NaN
# match_111      NaN        NaN       NaN       NaN           NaN        NaN
# match_112      NaN        NaN       NaN       NaN           NaN        NaN
# match_113      NaN        NaN       NaN       NaN           NaN        NaN
# match_114      NaN        NaN       NaN       NaN           NaN        NaN
# match_115      NaN        NaN       NaN       NaN           NaN        NaN
# match_116      NaN        NaN       NaN       NaN           NaN        NaN
# match_117      NaN        NaN       NaN       NaN           NaN        NaN
# match_118      NaN        NaN       NaN       NaN           NaN        NaN
# match_119      NaN        NaN       NaN       NaN           NaN        NaN
# match_12       NaN        NaN       NaN       NaN           NaN        NaN
# match_120      NaN        NaN       NaN       NaN           NaN        NaN
# match_121      NaN        NaN       NaN       NaN           NaN        NaN
# match_122      NaN        NaN       NaN       NaN           NaN        NaN
# match_123      NaN        NaN       NaN       NaN           NaN        NaN
# match_124      NaN        NaN       NaN       NaN           NaN        NaN
# ...            ...        ...       ...       ...           ...        ...
# match_72       NaN        NaN       NaN       NaN           NaN        NaN
# match_73       NaN        NaN       NaN       NaN           NaN        NaN
# match_74       NaN        NaN       NaN       NaN           NaN        NaN
# match_75       NaN        NaN       NaN       NaN           NaN        NaN
# match_76       NaN        NaN       NaN       NaN           NaN        NaN
# match_77       NaN        NaN       NaN       NaN           NaN        NaN
# match_78       NaN        NaN       NaN       NaN           NaN        NaN
# match_79       NaN        NaN       NaN       NaN           NaN        NaN
# match_8        NaN        NaN   English       NaN           NaN        NaN
# match_80       NaN        NaN       NaN       NaN           NaN        NaN
# match_81       NaN        NaN       NaN       NaN           NaN        NaN
# match_82       NaN        NaN       NaN       NaN           NaN        NaN
# match_83       NaN        NaN       NaN       NaN           NaN        NaN
# match_84       NaN        NaN       NaN   No Pets           NaN        NaN
# match_85       NaN        NaN       NaN       NaN       Spanish        NaN
# match_86       NaN        NaN       NaN       NaN           NaN        NaN
# match_87       NaN        NaN       NaN       NaN           NaN        NaN
# match_88       NaN        NaN       NaN       NaN           NaN        NaN
# match_89       NaN        NaN       NaN       NaN           NaN        NaN
# match_9        NaN        NaN       NaN       NaN           NaN        NaN
# match_90       NaN        NaN       NaN       NaN           NaN        NaN
# match_91       NaN        NaN       NaN       NaN           NaN    No Pets
# match_92       NaN        NaN       NaN       NaN           NaN        NaN
# match_93       NaN        NaN       NaN       NaN           NaN        NaN
# match_94       NaN        NaN       NaN       NaN           NaN        NaN
# match_95       NaN        NaN       NaN       NaN           NaN        NaN
# match_96       NaN        NaN       NaN       NaN           NaN        NaN
# match_97       NaN        NaN       NaN       NaN           NaN        NaN
# match_98       NaN        NaN       NaN       NaN           NaN        NaN
# match_99       NaN        NaN       NaN       NaN           NaN        NaN
#
# [598 rows x 156 columns]

# %%
# build new fields from existing data
dfAllf['Age'] = dfAllf['Details'].str.strip().str[0:2].astype('int')
dfAllf['Gender'] = dfAllf['Details'].str.strip().str[12:13]
dfAllf['Zodiac Sign'] = dfAllf['Ethnicity'].str.split(', ').str[1]
dfAllf['Ethnicity'] = dfAllf['Ethnicity'].str.split(', ').str[0]

# %%
# remove special characters from 'about me text'
def remove_punctuation(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    return s

dfAllf['about_me_text_clean']= dfAllf['about_me_text'].apply(remove_punctuation)

# %%
# export all data to CSV
dfAllf.to_csv('allFemale.csv')

# %%
# read JSON from file. "pof_output.txt" encoding is Windows-style "cp1252"
strPath = "Resources/pof_output_male.txt"
with open(strPath, 'r', encoding = 'cp1252') as file:
    strFilem = file.read()
    dictProfilem = ast.literal_eval(ast.literal_eval(strFilem).decode("utf-8"))

# %%
# AddFieldsFromDictCol() converts one dictionary-style column into multiple discrete columns
def AddFieldsFromDictCol(df, strDictCol):
    dfTemp = df[strDictCol].apply(pd.Series) # .apply(pd.Series) is my favorite method EVER
    for strCol in dfTemp.columns:
        if strCol.strip() not in df.columns:
            df[strCol.strip()] = dfTemp[strCol]
    return df

# %%
# dump all fields to dataframe
lstColm = ['username', 'headline', 'profile_info_1', 'profile_info_2', 'interests', 'about_me_text']
dfAllm = pd.DataFrame.from_dict(dictProfilem, orient = 'index', columns = lstColm)
# convert dictionary-style columns to discrete columns and drop the dictionary columns
for strColm in ['profile_info_1', 'profile_info_2']:
    dfAllm = AddFieldsFromDictCol(dfAllm, strColm)
    dfAllm = dfAllm.drop(strColm, axis=1)
# dump all recs lacking basic Details entry (eg: 66 year old Male, 5' 10" (178cm), Christian - other)
dfAllm = dfAllm.dropna(subset=['Details'], thresh = 1)
# handle NaNs and whitespace
dfAllm['Hair Color'] = dfAllm['Hair Color'].str.strip()
dfAllm['Pets'] = dfAllm['Pets'].fillna('No Pets')
dfAllm['Pets'] = dfAllm['Pets'].str.strip()

# %%
# build new fields from existing data
dfAllm['Age'] = dfAllm['Details'].str.strip().str[0:2].astype('int')
dfAllm['Gender'] = dfAllm['Details'].str.strip().str[12:13]
dfAllm['Zodiac Sign'] = dfAllm['Ethnicity'].str.split(', ').str[1]
dfAllm['Ethnicity'] = dfAllm['Ethnicity'].str.split(', ').str[0]

# %%
# remove special characters from 'about me text'
dfAllm['about_me_text_clean']= dfAllm['about_me_text'].apply(remove_punctuation)

# %%
# export all data to CSV
dfAllm.to_csv('allMale.csv')

# %%
# concatenate male and female dataframe
dfAll = dfAllf.append(dfAllm, ignore_index=True, sort=True)

# %%
# select only needed columns
dfAll = dfAll[['username','Gender', 'Education', 'Ethnicity', 'about_me_text_clean']]

# %%
# save combined csv to folder
dfAll.to_csv('all.csv')
